# %% [markdown]
# # 🔹 Qué hace este bloque
# - Recorre todas las categorías.
# - Extrae las categorias.

# %%
import requests # Bibliteca para hacer peticiones para abrir una pagina web desde mi codigo
from bs4 import BeautifulSoup # Herramienta para parsear HTML y extraer datos de forma amigable


# Defino la URL  del sitio principal
BASE_URL = "https://books.toscrape.com/"

#  Te lleva a la página donde están listadas todas las categorías.
CATEGORIAS_URL = BASE_URL + "index.html" 

def extraer_categorias():
    # Abre la pagina como si fuera un navegador y devuelve el contenido en formato HTML
    respuesta = requests.get(CATEGORIAS_URL)
    soup = BeautifulSoup(respuesta.text, "html.parser")# Convierto ese HTML en un objeto manipulable

    # Usa selectores CSS para encontrar elementos en el HTML
    categorias_links = soup.select("ul.nav-list ul li a") #etiqueta

    categoria = {} # Creo un diccionario vacio para guardar categorias

    for link in categorias_links: 
        nombre = link.text.strip() # Obtiene el link de la categoria y le quita espacios extra
        url_relativa = link['href'] # Saco la URL relativa 
        url_completa = BASE_URL + url_relativa # Armo la URL completa que te permiten navegar a cada categoría individualmente.
        categoria[nombre] = url_completa # Guardo en el diccionario: nombre -> URL

    print(f"Categorias encontradas: {len(categoria)}\n")
    return categoria
   

categoria = extraer_categorias()
# Out:
# Categorias encontradas: 50

# %% [markdown]
# # Creación de Base de Datos

# %%
import sqlite3

# Si el archivo no existe, lo crea. Si ya existe lo abre
conn = sqlite3.connect("libros.db") # Crea el archivo libros.db
cursor = conn.cursor() # Cursor es el "lapiz" con el que escribir y lees dentro de la base de datos

# execute -> ejecuta instrucción SQL dentro de la BD
cursor.execute("""
-- Evita errores si la tabla ya fue creada antes
CREATE TABLE IF NOT EXISTS categorias( 
    id INTEGER PRIMARY KEY AUTOINCREMENT, 
    nombre TEXT UNIQUE  -- UNIQUE Asegura que los valores de una columna no se repitan 
)
""")

cursor.execute("""
               
CREATE TABLE IF NOT EXISTS autores(
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    nombre TEXT UNIQUE
)
""")
cursor.execute("""
CREATE TABLE IF NOT EXISTS libros(
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    titulo TEXT,
    precio REAL,   --Tipo de dato numerico que representa numeros decimales o enteros 
    rating TEXT,
    disponibilidad TEXT,
    link TEXT,
    UPC TEXT,       --UPC-> Codigo universal del producto
    descripcion TEXT,
    FOREIGN KEY (categoria_id) REFERENCES categorias(id)                                
)
""")
try:
     cursor.execute("ALTER TABLE libros ADD COLUMN categoria_id TEXT")
except sqlite3.OperationalError: # Problemas operativos con la BD, (INSERTAR columna que ya existe)
     print("La columna 'categoria_id' ya existe.")



cursor.execute("""
CREATE TABLE IF NOT EXISTS libro_autor(
    libro_id INTEGER,
    autor_id INTEGER,
    PRIMARY KEY (libro_id, autor_id),
    FOREIGN KEY (libro_id) REFERENCES libros(id),
    FOREIGN KEY (autor_id) REFERENCES autores(id)
)
""")
cursor.execute("PRAGMA table_info(libros)") # Muestra la estructura de la tabla libros
print(cursor.fetchall())#Recupera todos los resultados y los imprime 
conn.commit() # Guarda todos los cambios realizados en la BD 
conn.close()
# Out:
# La columna 'categoria_id' ya existe.
# [(0, 'id', 'INTEGER', 0, None, 1), (1, 'titulo', 'TEXT', 0, None, 0), (2, 'categoria', 'TEXT', 0, None, 0), (3, 'precio', 'REAL', 0, None, 0), (4, 'rating', 'TEXT', 0, None, 0), (5, 'descripcion', 'TEXT', 0, None, 0), (6, 'disponibilidad', 'TEXT', 0, None, 0), (7, 'link', 'TEXT', 0, None, 0), (8, 'UPC', 'TEXT', 0, None, 0), (9, 'categoria_id', 'TEXT', 0, None, 0)]

# %% [markdown]
# # Conexion a la BD.
# - Insertar categorias
# - Insertar autores
# - Insertar libros
# - Relación libros con autor

# %%
import sqlite3

# Conexión a la BD
def conectar():
    return sqlite3.connect("libros.db")

# Guardar categoría
def guardar_categoria(nombre):
    conn = conectar()
    cursor = conn.cursor()
    # INSERT OR IGNORE -> Inserta la categoria solo si no existe
    cursor.execute("INSERT OR IGNORE INTO categorias(nombre) VALUES(?)", (nombre,))
    conn.commit()
    cursor.execute("SELECT id FROM categorias WHERE nombre=?", (nombre,)) # ?-> placeholdeer :espacio reservado dentro de una consulta SQL
    categoria_id = cursor.fetchone()[0] # - recupera la primera fila del resultado y extraer el primer valor
    conn.close()

    return categoria_id

# Guardar autor
def guardar_autor(nombre):
    conn = conectar()
    cursor = conn.cursor()
    cursor.execute("INSERT OR IGNORE INTO autores(nombre) VALUES(?)", (nombre,))
    conn.commit()
    cursor.execute("SELECT id FROM autores WHERE nombre=?", (nombre,))
    autor_id = cursor.fetchone()[0]
    conn.close()
    return autor_id

# Guardar libro
def guardar_libro(titulo, precio, rating, disponibilidad, link, UPC, categoria_id,descripcion):
    conn = conectar()
    cursor = conn.cursor()
    cursor.execute("""
        INSERT INTO libros(titulo, precio, rating, disponibilidad, link, UPC, categoria_id,descripcion)
        VALUES(?,?,?,?,?,?,?,?)
    """, (titulo, precio, rating, disponibilidad, link, UPC, categoria_id, descripcion))
    conn.commit()
    libro_id = cursor.lastrowid # Devuelve el id de la ultima fila insertada por ese cursor
    conn.close()
    return libro_id

# Relacionar libro con autor
def guardar_libro_autor(libro_id, autor_id):
    conn = conectar()
    cursor = conn.cursor()
    cursor.execute("INSERT OR IGNORE INTO libro_autor(libro_id, autor_id) VALUES(?,?)", (libro_id, autor_id))
    conn.commit()
    conn.close()

# %% [markdown]
# # Consultas Google Books API

# %%
import requests
from bs4 import BeautifulSoup

# --- Scraping en BooksToScrape (por autor) ---
def obtener_autor_books_to_scrape(url_libro):
    try:
        response = requests.get(url_libro)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            info_table = soup.select('table.table.table-striped tr')
            if len(info_table) > 1: # si hay mas de una fila
                autor = info_table[1].text.strip() # toma la segunda que suele contener el autor, limpia espacion y devuelve
                return autor
    except Exception as e:
        print(f"Error en scraping: {e}")
    return "Autor desconocido"


# --- API de Google Books ---
def buscar_libro(titulo):
    url = "https://www.googleapis.com/books/v1/volumes"
    params = {
        "q": f"intitle:{titulo}", # busca por titulo
        "maxResults": 1, # limita a 1 resultado(para evitar multiples coincidencias)
        "langRestrict": "es" # filtra por idioma español
    }

    respuesta = requests.get(url, params=params) #Hace la petición con los parámetros definidos

    if respuesta.status_code == 200:
        datos = respuesta.json()
        if "items" in datos:
            info = datos["items"][0]["volumeInfo"] # Si hay resultados,toma el primero y accede a su info

            titulo_libro = info.get("title", "Sin título")
            autores = ", ".join(info.get("authors", ["Autor desconocido"]))
            descripcion = info.get("description", "Sin descripción")

            return {
                "Título": titulo_libro,
                "Autores": autores,
                "Descripción": descripcion
            }

    # Si no encuentra en la API, intenta con BooksToScrape
    print("No se encontró en Google Books, intentando en BooksToScrape...")
    autor_scrape = obtener_autor_books_to_scrape("http://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html")

    return {
        "Título": "No encontrado",
        "Autores": autor_scrape,
        "Descripción": "No disponible"
    }


# --- Ejemplo de uso ---
print(buscar_libro("A Light in the Attic"))
# Out:
# {'Título': 'A Light in the Attic', 'Autores': 'Shel Silverstein', 'Descripción': "NOW AVAILABLE AS AN EBOOK! From New York Times bestselling author Shel Silverstein, the creator of the beloved poetry collections Where the Sidewalk Ends, Falling Up, and Every Thing On It, comes an imaginative book of poems and drawings—a favorite of Shel Silverstein fans young and old. This digital edition also includes twelve poems previously only available in the special edition hardcover. A Light in the Attic delights with remarkable characters and hilariously profound poems in a collection readers will return to again and again. Here in the attic you will find Backward Bill, Sour Face Ann, the Meehoo with an Exactlywatt, and the Polar Bear in the Frigidaire. You will talk with Broiled Face, and find out what happens when Somebody steals your knees, you get caught by the Quick-Digesting Gink, a Mountain snores, and They Put a Brassiere on the Camel. Come on up to the attic of Shel Silverstein and let the light bring you home. And don't miss these other Shel Silverstein ebooks, The Giving Tree, Where the Sidewalk Ends, and Falling Up!"}

# %%
# Función para obtener detalle completo de un libro
def obtener_detalle_libro(url_libro, categoria):
    try:
        response = requests.get(url_libro)
        soup = BeautifulSoup(response.text, "html.parser")
        
        titulo = soup.select_one(".product_main h1").get_text(strip=True)
        precio_text = soup.select_one(".price_color").get_text(strip=True)
        
        # Limpiar precio de manera más robusta
        try:
            precio_limpio = precio_text.replace('£', '').replace('Â', '').replace('€', '').strip()
            precio = float(precio_limpio)
        except ValueError:
            precio = 0.0  # Precio por defecto si no se puede convertir
            
        
        
        disponibilidad = soup.select_one(".instock.availability").get_text(strip=True)
        
        # Rating (está en class="star-rating X")
        rating_tag = soup.select_one(".star-rating")
        rating = rating_tag["class"][1] if rating_tag else "Sin rating"

        # UPC (está en la tabla de detalles)
        info_table = soup.select("table.table.table-striped tr")
        upc = info_table[0].td.get_text(strip=True) if len(info_table) > 0 else "Sin UPC"
        
        # Descripción del producto
        descripcion_tag = soup.select_one("#product_description ~ p")
        descripcion = descripcion_tag.get_text(strip=True) if descripcion_tag else "Sin descripción"

        # Buscar autor usando Google Books API
        info_google = buscar_libro(titulo)
        autor = info_google.get("Autores", "Autor desconocido")
        
        # Si Google no tiene descripción, usar la del sitio
        if info_google.get("Descripción") != "Sin descripción":
            descripcion = info_google.get("Descripción", descripcion)

        return {
            "titulo": titulo,
            "autor": autor,
            "precio": precio,
            "rating": rating,
            "disponibilidad": disponibilidad,
            "categoria": categoria,
            "link": url_libro,
            "UPC": upc,
            "descripcion": descripcion
        }
    except Exception as e:
        print(f"Error al obtener {url_libro}: {e}")
        return None

# %% [markdown]
# #  OBTENER LIBROS POR CATEGORIAS

# %%
import time # Para no hacer pedidos(requests) una tras otra, porque puede causar problemas

"""Creo una función y le doy dos argumentos"""
def obtener_libros_por_categoria(nombre_categoria,url_categoria):

    
    pagina_actual = url_categoria #Asigna la URL inicial de la categoría a una variable que iremos actualizando
    libros = [] # Lista vacía en donde se va guardar un diccionario por cada libro

    while True:
        print(f"Scrapeando {pagina_actual}...")
        respuesta = requests.get(pagina_actual)
        soup = BeautifulSoup(respuesta.text, "html.parser")

        libros_en_pagina = soup.select(".product_pod")
        
        for libro in libros_en_pagina:
            titulo = libro.h3.a["title"]
            precio = libro.select_one(".price_color").text.strip()
            rating = libro.p["class"][1] # Investigar

            url_relativa = libro.h3.a["href"]
            url_libro = "/".join(pagina_actual.split("/")[:-1]) + "/" + url_relativa # investigar

            

            libros.append({
                "categoria": nombre_categoria,
                "titulo": titulo,
                "precio": precio,
                "rating": rating,
                "url_libro": url_libro,
               
            })


        next_button = soup.select_one("li.next a") # Busca si hay un enlace a la próxima página. Si existe, sigue
        # Construye la URL de la próxima página
        if next_button:
            next_url = next_button["href"]
            # Si pagina_actual = ".../index.html" y next_url = "page-2.html"➡ Reemplaza index.html con page-2.html
            if "index.html" in pagina_actual:
                pagina_actual = pagina_actual.replace("index.html", next_url )
            else:
                # Esta línea se ejecuta cuando hay más de una página en la categoría (ejemplo: page-2.html, page-3.html, etc.).
                pagina_actual = "/".join(pagina_actual.split("/")[:-1])+ "/" + next_url
        else: 
            break

        time.sleep(1) # Espera 1 segundo antes de pasar a la próxima página
    return libros # Devuelve la lista de diccionarios con todos los libros encontrados
#  lista vacía para juntar todos los libros del sitio
todos_los_libros = []
# Recorre todas las categorías que ya tenemos en el diccionario
for nombre,url in categoria.items():
    print(f"Scrapeando categoría: {nombre}...")

    libros_categoria = obtener_libros_por_categoria(nombre,url)

    todos_los_libros.extend(libros_categoria)  # agregamos todos los libros a la lista general
print(f"\nScraping completado. Total de libros encontrados: {len(todos_los_libros)}")
# Out:
# Scrapeando categoría: Travel...
# Scrapeando https://books.toscrape.com/catalogue/category/books/travel_2/index.html...
# Scrapeando categoría: Mystery...
# Scrapeando https://books.toscrape.com/catalogue/category/books/mystery_3/index.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/mystery_3/page-2.html...
# Scrapeando categoría: Historical Fiction...
# Scrapeando https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/historical-fiction_4/page-2.html...
# Scrapeando categoría: Sequential Art...
# Scrapeando https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/sequential-art_5/page-2.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/sequential-art_5/page-3.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/sequential-art_5/page-4.html...
# Scrapeando categoría: Classics...
# Scrapeando https://books.toscrape.com/catalogue/category/books/classics_6/index.html...
# Scrapeando categoría: Philosophy...
# Scrapeando https://books.toscrape.com/catalogue/category/books/philosophy_7/index.html...
# Scrapeando categoría: Romance...
# Scrapeando https://books.toscrape.com/catalogue/category/books/romance_8/index.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books
://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/food-and-drink_33/page-2.html...
# Scrapeando categoría: Christian Fiction...
# Scrapeando https://books.toscrape.com/catalogue/category/books/christian-fiction_34/index.html...
# Scrapeando categoría: Business...
# Scrapeando https://books.toscrape.com/catalogue/category/books/business_35/index.html...
# Scrapeando categoría: Biography...
# Scrapeando https://books.toscrape.com/catalogue/category/books/biography_36/index.html...
# Scrapeando categoría: Thriller...
# Scrapeando https://books.toscrape.com/catalogue/category/books/thriller_37/index.html...
# Scrapeando categoría: Contemporary...
# Scrapeando https://books.toscrape.com/catalogue/category/books/contemporary_38/index.html...
# Scrapeando categoría: Spirituality...
# Scrapeando https://books.toscrape.com/catalogue/category/books/spirituality_39/index.html...
# Scrapeando categoría: Academic...
# Scrapeando https://books.toscrape.com/catalogue/category/books/academic_40/index.html...
# Scrapeando categoría: Self Help...
# Scrapeando https://books.toscrape.com/catalogue/category/books/self-help_41/index.html...
# Scrapeando categoría: Historical...
# Scrapeando https://books.toscrape.com/catalogue/category/books/historical_42/index.html...
# Scrapeando categoría: Christian...
# Scrapeando https://books.toscrape.com/catalogue/category/books/christian_43/index.html...
# Scrapeando categoría: Suspense...
# Scrapeando https://books.toscrape.com/catalogue/category/books/suspense_44/index.html...
# Scrapeando categoría: Short Stories...
# Scrapeando https://books.toscrape.com/catalogue/category/books/short-stories_45/index.html...
# Scrapeando categoría: Novels...
# Scrapeando https://books.toscrape.com/catalogue/category/books/novels_46/index.html...
# Scrapeando categoría: Health...
# Scrapeando https://books.toscrape.com/catalogue/category/books/health_47/index.html...
# Scrapeando categoría: Politics...
# Scrapeando https://books.toscrape.com/catalogue/category/books/politics_48/index.html...
# Scrapeando categoría: Cultural...
# Scrapeando https://books.toscrape.com/catalogue/category/books/cultural_49/index.html...
# Scrapeando categoría: Erotica...
# Scrapeando https://books.toscrape.com/catalogue/category/books/erotica_50/index.html...
# Scrapeando categoría: Crime...
# Scrapeando https://books.toscrape.com/catalogue/category/books/crime_51/index.html...
#
# Scraping completado. Total de libros encontrados: 1000

# %%
# LIMPIAR Y GUARDAR LOS DATOS EN LA BASE DE DATOS
print("\n💾 Guardando datos en la base de datos...")

contador_guardados = 0

for libro in todos_los_libros:
    try:
        # Limpiar el precio
        precio_texto = libro['precio']
        precio_limpio = precio_texto.replace('£', '').replace('Â', '').strip()
        precio_float = float(precio_limpio)
        
        # Guardar categoría si no existe y obtener ID
        categoria_id = guardar_categoria(libro['categoria'])
        
        # Guardar libro en BD
        libro_id = guardar_libro(
            libro['titulo'],
            precio_float,  # Precio ya convertido a float
            libro['rating'],
            "In stock",  # Disponibilidad por defecto
            libro['url_libro'],
            "N/A",  # UPC no disponible en listado # investigar
            categoria_id,
            "Descripción no disponible"  # Descripción por defecto
        )
        
        # Para el autor, usar un nombre genérico por ahora
      # investigar
        autor_id = guardar_autor("Autor por determinar")
        guardar_libro_autor(libro_id, autor_id)
        
        contador_guardados += 1
        
        if contador_guardados % 100 == 0:
            print(f"   📚 {contador_guardados} libros guardados...")
            
    except Exception as e:
        print(f"   ❌ Error guardando '{libro['titulo']}': {e}")
        continue

print(f"\n🎉 GUARDADO COMPLETADO!")
print(f"📊 {contador_guardados} libros guardados exitosamente")
print(f"🗃️ Base de datos 'libros.db' lista para las consultas")
# Out:
# 💾 Guardando datos en la base de datos...
#    📚 100 libros guardados...
#    📚 200 libros guardados...
#    📚 300 libros guardados...
#    📚 400 libros guardados...
#    📚 500 libros guardados...
#    📚 600 libros guardados...
#    📚 700 libros guardados...
#    📚 800 libros guardados...
#    📚 900 libros guardados...
#    📚 1000 libros guardados...
#
# 🎉 GUARDADO COMPLETADO!
# 📊 1000 libros guardados exitosamente
# 🗃️ Base de datos 'libros.db' lista para las consultas

# %% [markdown]
# #  EJECUCION DE SCRAPING COMPLETO

# %%
# SCRAPING COMPLETO CON GUARDADO EN BASE DE DATOS
def ejecutar_scraping_completo():
    """
    Ejecuta el scraping completo del sitio y guarda todo en la base de datos
    """
    print("🕷️ Iniciando misión: Infiltración en Books To Scrape...")
    
    # Obtener todas las categorías
    categorias = extraer_categorias()
    
    contador_libros = 0
    
    # Recorrer cada categoría
    for nombre_categoria, url_categoria in categorias.items():
        print(f"\n📚 Scrapeando categoría: {nombre_categoria}")
        
        # Guardar categoría en BD y obtener su ID
        categoria_id = guardar_categoria(nombre_categoria)
        
        # Obtener libros básicos de la categoría
        libros_categoria = obtener_libros_por_categoria(nombre_categoria, url_categoria)
        
        # Procesar cada libro para obtener detalles completos
        for libro_basico in libros_categoria:
            print(f"  📖 Procesando: {libro_basico['titulo']}")
            
            # Obtener detalles completos del libro
            detalle = obtener_detalle_libro(libro_basico['url_libro'], nombre_categoria)
            
            if detalle:
                # Guardar libro en BD
                libro_id = guardar_libro(
                    detalle['titulo'],
                    detalle['precio'],
                    detalle['rating'],
                    detalle['disponibilidad'],
                    detalle['link'],
                    detalle['UPC'],
                    categoria_id,
                    detalle['descripcion']
                )
                
                # Procesar autores (pueden ser múltiples separados por coma)
                autores = detalle['autor'].split(', ')
                for autor_nombre in autores:
                    autor_nombre = autor_nombre.strip()
                    if autor_nombre and autor_nombre != "Autor desconocido":
                        # Guardar autor y relacionar con libro
                        autor_id = guardar_autor(autor_nombre)
                        guardar_libro_autor(libro_id, autor_id)
                
                contador_libros += 1
                
                # Pequeña pausa para no sobrecargar el servidor
                time.sleep(0.5)
        
        print(f"✅ Categoría {nombre_categoria} completada")
        time.sleep(1)  # Pausa entre categorías
    
    print(f"\n🎉 MISIÓN COMPLETADA!")
    print(f"📊 Total de libros procesados: {contador_libros}")
    print(f"🗃️ Base de datos 'libros.db' lista para la acción")
ejecutar_scraping_completo()
# Ejecutar el scraping completo
# ¡CUIDADO! Esto puede tomar bastante tiempo
# Out:
# 🕷️ Iniciando misión: Infiltración en Books To Scrape...
# Categorias encontradas: 50
#
#
# 📚 Scrapeando categoría: Travel
# Scrapeando https://books.toscrape.com/catalogue/category/books/travel_2/index.html...
#   📖 Procesando: It's Only the Himalayas
#   📖 Procesando: Full Moon over Noahâs Ark: An Odyssey to Mount Ararat and Beyond
#   📖 Procesando: See America: A Celebration of Our National Parks & Treasured Sites
#   📖 Procesando: Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel
#   📖 Procesando: Under the Tuscan Sun
#   📖 Procesando: A Summer In Europe
#   📖 Procesando: The Great Railway Bazaar
#   📖 Procesando: A Year in Provence (Provence #1)
#   📖 Procesando: The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)
#   📖 Procesando: Neither Here nor There: Travels in Europe
#   📖 Procesando: 1,000 Places to See Before You Die
# ✅ Categoría Travel completada
#
# 📚 Scrapeando categoría: Mystery
# Scrapeando https://books.toscrape.com/catalogue/category/books/mystery_3/index.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/mystery_3/page-2.html...
#   📖 Procesando: Sharp Objects
#   📖 Procesando: In a Dark, Dark Wood
#   📖 Procesando: The Past Never Ends
#   📖 Procesando: A Murder in Time
#   📖 Procesando: The Murder of Roger Ackroyd (Hercule Poirot #4)
#   📖 Procesando: The Last Mile (Amos Decker #2)
#   📖 Procesando: That Darkness (Gardiner and Renner #1)
#   📖 Procesando: Tastes Like Fear (DI Marnie Rome #3)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: A Time of Torment (Charlie Parker #14)
#   📖 Procesando: A Study in Scarlet (Sherlock Holmes #1)
#   📖 Procesando: Poisonous (Max Revere Novels #3)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Murder at the 42nd Street Library (Raymond Ambler #1)
#   📖 Procesando: Most Wanted
#   📖 Procesando: Hide Away (Eve Duncan #20)
#   📖 Procesando: Boar Island (Anna Pigeon #19)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: The Widow
#   📖 Procesando: Playing with Fire
#   📖 Procesando: What Happened on Beale Street (Secrets of the South Mysteries #2)
#   📖 Procesando: The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Delivering the Truth (Quaker Midwife Mystery #1)
#   📖 Procesando: The Mysterious Affair at Styles (Hercule Poirot #1)
#   📖 Procesando: In the Woods (Dublin Murder Squad #1)
#   📖 Procesando: The Silkworm (Cormoran Strike #2)
#   📖 Procesando: The Exiled
#   📖 Procesando: The Cuckoo's Calling (Cormoran Strike #1)
#   📖 Procesando: Extreme Prey (Lucas Davenport #26)
#   📖 Procesando: Career of Evil (Cormoran Strike #3)
#   📖 Procesando: The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)
#   📖 Procesando: The Girl You Lost
#   📖 Procesando: The Girl In The Ice (DCI Erika Foster #1)
#   📖 Procesando: Blood Defense (Samantha Brinkman #1)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: 1st to Die (Women's Murder Club #1)
# ✅ Categoría Mystery completada
#
# 📚 Scrapeando categoría: Historical Fiction
# Scrapeando https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/historical-fiction_4/page-2.html...
#   📖 Procesando: Tipping the Velvet
#   📖 Procesando: Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton
#   📖 Procesando: A Flight of Arrows (The Pathfinders #2)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: The House by the Lake
#   📖 Procesando: Mrs. Houdini
#   📖 Procesando: The Marriage of Opposites
#   📖 Procesando: Glory over Everything: Beyond The Kitchen House
#   📖 Procesando: Love, Lies and Spies
#   📖 Procesando: A Paris Apartment
#   📖 Procesando: Lilac Girls
#   📖 Procesando: The Constant Princess (The Tudor Court #1)
#   📖 Procesando: The Invention of Wings
#   📖 Procesando: World Without End (The Pillars of the Earth #2)
#   📖 Procesando: The Passion of Dolssa
#   📖 Procesando: Girl With a Pearl Earring
#   📖 Procesando: Voyager (Outlander #3)
#   📖 Procesando: The Red Tent
#   📖 Procesando: The Last Painting of Sara de Vos
#   📖 Procesando: The Guernsey Literary and Potato Peel Pie Society
#   📖 Procesando: Girl in the Blue Coat
#   📖 Procesando: Between Shades of Gray
#   📖 Procesando: While You Were Mine
#   📖 Procesando: The Secret Healer
#   📖 Procesando: Starlark
#   📖 Procesando: Lost Among the Living
#   📖 Procesando: A Spy's Devotion (The Regency Spies of London #1)
# ✅ Categoría Historical Fiction completada
#
# 📚 Scrapeando categoría: Sequential Art
# Scrapeando https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/sequential-art_5/page-2.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/sequential-art_5/page-3.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/sequential-art_5/page-4.html...
#   📖 Procesando: Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)
#   📖 Procesando: Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)
#   📖 Procesando: This One Summer
#   📖 Procesando: The Nameless City (The Nameless City #1)
#   📖 Procesando: Saga, Volume 5 (Saga (Collected Editions) #5)
#   📖 Procesando: Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)
#   📖 Procesando: Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)
#   📖 Procesando: Pop Gun War, Volume 1: Gift
#   📖 Procesando: Patience
#   📖 Procesando: Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)
#   📖 Procesando: orange: The Complete Collection 1 (orange: The Complete Collection #1)
#   📖 Procesando: Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)
#   📖 Procesando: Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)
#   📖 Procesando: Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)
#   📖 Procesando: I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)
#   📖 Procesando: I am a Hero Omnibus Volume 1
#   📖 Procesando: Giant Days, Vol. 2 (Giant Days #5-8)
#   📖 Procesando: Danganronpa Volume 1
#   📖 Procesando: Codename Baboushka, Volume 1: The Conclave of Death
#   📖 Procesando: Camp Midnight
#   📖 Procesando: Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))
#   📖 Procesando: The Shadow Hero (The Shadow Hero)
#   📖 Procesando: Fables, Vol. 1: Legends in Exile (Fables #1)
#   📖 Procesando: Batman: The Long Halloween (Batman)
#   📖 Procesando: Batman: The Dark Knight Returns (Batman)
#   📖 Procesando: Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)
#   📖 Procesando: We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)
#   📖 Procesando: Through the Woods
#   📖 Procesando: Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)
#   📖 Procesando: So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)
#   📖 Procesando: Robin War
#   📖 Procesando: Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)
#   📖 Procesando: Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14)
#   📖 Procesando: Lowriders to the Center of the Earth (Lowriders in Space #2)
#   📖 Procesando: El Deafo
#   📖 Procesando: Batman: Europa
#   📖 Procesando: Art Ops Vol. 1
#   📖 Procesando: Adulthood Is a Myth: A "Sarah's Scribbles" Collection
#   📖 Procesando: Fruits Basket, Vol. 9 (Fruits Basket #9)
#   📖 Procesando: Roller Girl
#   📖 Procesando: Fruits Basket, Vol. 7 (Fruits Basket #7)
#   📖 Procesando: Fruits Basket, Vol. 6 (Fruits Basket #6)
#   📖 Procesando: Death Note, Vol. 6: Give-and-Take (Death Note #6)
#   📖 Procesando: Fruits Basket, Vol. 5 (Fruits Basket #5)
#   📖 Procesando: Death Note, Vol. 5: Whiteout (Death Note #5)
#   📖 Procesando: The Demon Prince of Momochi House, Vol. 4 (The Demon Prince of Momochi House #4)
#   📖 Procesando: Fruits Basket, Vol. 4 (Fruits Basket #4)
#   📖 Procesando: The Wicked + The Divine, Vol. 3: Commercial Suicide (The Wicked + The Divine)
#   📖 Procesando: The Sandman, Vol. 3: Dream Country (The Sandman (volumes) #3)
#   📖 Procesando: Saga, Volume 3 (Saga (Collected Editions) #3)
#   📖 Procesando: Prodigy: The Graphic Novel (Legend: The Graphic Novel #2)
#   📖 Procesando: Persepolis: The Story of a Childhood (Persepolis #1-2)
#   📖 Procesando: Original Fake
#   📖 Procesando: Grayson, Vol 3: Nemesis (Grayson #3)
#   📖 Procesando: Fruits Basket, Vol. 3 (Fruits Basket #3)
#   📖 Procesando: Black Butler, Vol. 1 (Black Butler #1)
#   📖 Procesando: Awkward
#   📖 Procesando: The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2)
#   📖 Procesando: Saga, Volume 2 (Saga (Collected Editions) #2)
#   📖 Procesando: Fruits Basket, Vol. 2 (Fruits Basket #2)
#   📖 Procesando: Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)
#   📖 Procesando: The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)
#   📖 Procesando: The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)
#   📖 Procesando: The Complete Maus (Maus #1-2)
#   📖 Procesando: Skip Beat!, Vol. 01 (Skip Beat! #1)
#   📖 Procesando: Saga, Volume 1 (Saga (Collected Editions) #1)
#   📖 Procesando: Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)
#   📖 Procesando: Paper Girls, Vol. 1 (Paper Girls #1-5)
#   📖 Procesando: Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)
#   📖 Procesando: Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)
#   📖 Procesando: Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)
#   📖 Procesando: Giant Days, Vol. 1 (Giant Days #1-4)
#   📖 Procesando: Fruits Basket, Vol. 1 (Fruits Basket #1)
#   📖 Procesando: Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)
#   📖 Procesando: Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)
# ✅ Categoría Sequential Art completada
#
# 📚 Scrapeando categoría: Classics
# Scrapeando https://books.toscrape.com/catalogue/category/books/classics_6/index.html...
#   📖 Procesando: The Secret Garden
#   📖 Procesando: The Metamorphosis
#   📖 Procesando: The Pilgrim's Progress
#   📖 Procesando: The Hound of the Baskervilles (Sherlock Holmes #5)
#   📖 Procesando: Little Women (Little Women #1)
#   📖 Procesando: Gone with the Wind
#   📖 Procesando: Candide
#   📖 Procesando: Animal Farm
#   📖 Procesando: Wuthering Heights
#   📖 Procesando: The Picture of Dorian Gray
#   📖 Procesando: The Complete Stories and Poems (The Works of Edgar Allan Poe [Cameo Edition])
#   📖 Procesando: Beowulf
#   📖 Procesando: And Then There Were None
#   📖 Procesando: The Story of Hong Gildong
#   📖 Procesando: The Little Prince
#   📖 Procesando: Sense and Sensibility
#   📖 Procesando: Of Mice and Men
#   📖 Procesando: Emma
#   📖 Procesando: Alice in Wonderland (Alice's Adventures in Wonderland #1)
# ✅ Categoría Classics completada
#
# 📚 Scrapeando categoría: Philosophy
# Scrapeando https://books.toscrape.com/catalogue/category/books/philosophy_7/index.html...
#   📖 Procesando: Sophie's World
#   📖 Procesando: The Death of Humanity: and the Case for Life
#   📖 Procesando: The Stranger
#   📖 Procesando: Proofs of God: Classical Arguments from Tertullian to Barth
#   📖 Procesando: Kierkegaard: A Christian Missionary to Christians
#   📖 Procesando: At The Existentialist CafÃ©: Freedom, Being, and apricot cocktails with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and others
#   📖 Procesando: Critique of Pure Reason
#   📖 Procesando: Run, Spot, Run: The Ethics of Keeping Pets
#   📖 Procesando: The Nicomachean Ethics
#   📖 Procesando: Meditations
#   📖 Procesando: Beyond Good and Evil
# ✅ Categoría Philosophy completada
#
# 📚 Scrapeando categoría: Romance
# Scrapeando https://books.toscrape.com/catalogue/category/books/romance_8/index.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/romance_8/page-2.html...
#   📖 Procesando: Chase Me (Paris Nights #2)
#   📖 Procesando: Black Dust
#   📖 Procesando: Her Backup Boyfriend (The Sorensen Family #1)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: First and First (Five Boroughs #3)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Fifty Shades Darker (Fifty Shades #2)
#   📖 Procesando: The Wedding Dress
#   📖 Procesando: Suddenly in Love (Lake Haven #1)
#   📖 Procesando: Something More Than This
#   📖 Procesando: Doing It Over (Most Likely To #1)
#   📖 Procesando: The Wedding Pact (The O'Malleys #2)
#   📖 Procesando: Hold Your Breath (Search and Rescue #1)
#   📖 Procesando: Dirty (Dive Bar #1)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Take Me Home Tonight (Rock Star Romance #3)
#   📖 Procesando: Off the Hook (Fishing for Trouble #1)
#   📖 Procesando: A Gentleman's Position (Society of Gentlemen #3)
#   📖 Procesando: Sit, Stay, Love
#   📖 Procesando: A Girl's Guide to Moving On (New Beginnings #2)
#   📖 Procesando: The Perfect Play (Play by Play #1)
#   📖 Procesando: Dark Lover (Black Dagger Brotherhood #1)
#   📖 Procesando: Changing the Game (Play by Play #2)
#   📖 Procesando: A Walk to Remember
#   📖 Procesando: The Purest Hook (Second Circle Tattoos #3)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: The Obsession
#   📖 Procesando: Reservations for Two
#   📖 Procesando: Best of My Love (Fool's Gold #20)
#   📖 Procesando: Where Lightning Strikes (Bleeding Stars #3)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: This One Moment (Pushing Limits #1)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Rhythm, Chord & Malykhin
#   📖 Procesando: My Perfect Mistake (Over the Top #1)
#   📖 Procesando: Listen to Me (Fusion #1)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Imperfect Harmony
#   📖 Procesando: Fighting Fate (Fighting #6)
#   📖 Procesando: Deep Under (Walker Security #1)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Charity's Cross (Charles Towne Belles #4)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Bounty (Colorado Mountain #7)
# No se encontró en Google Books, intentando en BooksToScrape...
# ✅ Categoría Romance completada
#
# 📚 Scrapeando categoría: Womens Fiction
# Scrapeando https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html...
#   📖 Procesando: I Had a Nice Time And Other Lies...: How to find love & sh*t like that
#   📖 Procesando: Will You Won't You Want Me?
#   📖 Procesando: Keep Me Posted
#   📖 Procesando: Grey (Fifty Shades #4)
#   📖 Procesando: Meternity
#   📖 Procesando: Some Women
#   📖 Procesando: Shopaholic Ties the Knot (Shopaholic #3)
#   📖 Procesando: Can You Keep a Secret?
#   📖 Procesando: Twenties Girl
#   📖 Procesando: The Undomestic Goddess
#   📖 Procesando: The Nanny Diaries (Nanny #1)
#   📖 Procesando: The Devil Wears Prada (The Devil Wears Prada #1)
#   📖 Procesando: Something Borrowed (Darcy & Rachel #1)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Something Blue (Darcy & Rachel #2)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: I've Got Your Number
#   📖 Procesando: The Edge of Reason (Bridget Jones #2)
#   📖 Procesando: Bridget Jones's Diary (Bridget Jones #1)
# ✅ Categoría Womens Fiction completada
#
# 📚 Scrapeando categoría: Fiction
# Scrapeando https://books.toscrape.com/catalogue/category/books/fiction_10/index.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/fiction_10/page-2.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/fiction_10/page-3.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/fiction_10/page-4.html...
#   📖 Procesando: Soumission
#   📖 Procesando: Private Paris (Private #10)
#   📖 Procesando: We Love You, Charlie Freeman
#   📖 Procesando: Thirst
#   📖 Procesando: The Murder That Never Was (Forensic Instincts #5)
#   📖 Procesando: Tuesday Nights in 1980
#   📖 Procesando: The Vacationers
#   📖 Procesando: The Regional Office Is Under Attack!
#   📖 Procesando: Finders Keepers (Bill Hodges Trilogy #2)
#   📖 Procesando: The Time Keeper
#   📖 Procesando: The Testament of Mary
#   📖 Procesando: The First Hostage (J.B. Collins #2)
#   📖 Procesando: Take Me with You
#   📖 Procesando: Still Life with Bread Crumbs
#   📖 Procesando: Shtum
#   📖 Procesando: My Name Is Lucy Barton
#   📖 Procesando: My Mrs. Brown
#   📖 Procesando: Mr. Mercedes (Bill Hodges Trilogy #1)
#   📖 Procesando: I Am Pilgrim (Pilgrim #1)
#   📖 Procesando: Eligible (The Austen Project #4)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Eight Hundred Grapes
#   📖 Procesando: Dear Mr. Knightley
#   📖 Procesando: Cometh the Hour (The Clifton Chronicles #6)
#   📖 Procesando: Balloon Animals
#   📖 Procesando: A Man Called Ove
#   📖 Procesando: The Silent Sister (Riley MacPherson #1)
#   📖 Procesando: The Dinner Party
#   📖 Procesando: The Improbability of Love
#   📖 Procesando: Mothering Sunday
#   📖 Procesando: Lies and Other Acts of Love
#   📖 Procesando: Daredevils
#   📖 Procesando: 11/22/63
#   📖 Procesando: The Shack
#   📖 Procesando: The High Mountains of Portugal
#   📖 Procesando: Miller's Valley
#   📖 Procesando: Hystopia: A Novel
#   📖 Procesando: The Bourne Identity (Jason Bourne #1)
#   📖 Procesando: Sister Dear
#   📖 Procesando: Memoirs of a Geisha
#   📖 Procesando: Me Before You (Me Before You #1)
#   📖 Procesando: Deception Point
#   📖 Procesando: The Little Paris Bookshop
#   📖 Procesando: The Firm
#   📖 Procesando: The Expatriates
#   📖 Procesando: Siddhartha
#   📖 Procesando: Last One Home (New Beginnings #1)
#   📖 Procesando: Digital Fortress
#   📖 Procesando: Atlas Shrugged
#   📖 Procesando: Three-Martini Lunch
#   📖 Procesando: The Nightingale
#   📖 Procesando: The Infinities
#   📖 Procesando: The Husband's Secret
#   📖 Procesando: The Da Vinci Code (Robert Langdon #2)
#   📖 Procesando: The Art of Fielding
#   📖 Procesando: Lila (Gilead #3)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Jurassic Park (Jurassic Park #1)
#   📖 Procesando: Inferno (Robert Langdon #4)
#   📖 Procesando: Crazy Rich Asians (Crazy Rich Asians #1)
#   📖 Procesando: Big Little Lies
#   📖 Procesando: The Course of Love
#   📖 Procesando: When I'm Gone
#   📖 Procesando: The Silent Wife
#   📖 Procesando: The Bette Davis Club
#   📖 Procesando: Kitchens of the Great Midwest
#   📖 Procesando: Bright Lines
# ✅ Categoría Fiction completada
#
# 📚 Scrapeando categoría: Childrens
# Scrapeando https://books.toscrape.com/catalogue/category/books/childrens_11/index.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/childrens_11/page-2.html...
#   📖 Procesando: Birdsong: A Story in Pictures
#   📖 Procesando: The Bear and the Piano
#   📖 Procesando: The Secret of Dreadwillow Carse
#   📖 Procesando: The White Cat and the Monk: A Retelling of the Poem âPangur BÃ¡nâ
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando:
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Musicophilia: Tales of Music and the Brain
#   📖 Procesando: What If?: Serious Scientific Answers to Absurd Hypothetical Questions
#   📖 Procesando: The Fault in Our Stars
#   📖 Procesando: The Dream Thieves (The Raven Cycle #2)
#   📖 Procesando: The 5th Wave (The 5th Wave #1)
#   📖 Procesando: Shiver (The Wolves of Mercy Falls #1)
#   📖 Procesando: Remember Me?
#   📖 Procesando: If I Stay (If I Stay #1)
#   📖 Procesando: I Know Why the Caged Bird Sings (Maya Angelou's Autobiography #1)
#   📖 Procesando: Harry Potter and the Deathly Hallows (Harry Potter #7)
#   📖 Procesando: Fool Me Once
#   📖 Procesando: Drama
#   📖 Procesando: Blue Lily, Lily Blue (The Raven Cycle #3)
#   📖 Procesando: Alight (The Generations Trilogy #2)
#   📖 Procesando: Vogue Colors A to Z: A Fashion Coloring Book
#   📖 Procesando: The Shining (The Shining #1)
#   📖 Procesando: The Hunger Games (The Hunger Games #1)
#   📖 Procesando: Outlander (Outlander #1)
#   📖 Procesando: Mockingjay (The Hunger Games #3)
#   📖 Procesando: Harry Potter and the Sorcerer's Stone (Harry Potter #1)
#   📖 Procesando: Confessions of a Shopaholic (Shopaholic #1)
#   📖 Procesando: Zero History (Blue Ant #3)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: World War Z: An Oral History of the Zombie War
#   📖 Procesando: Wild: From Lost to Found on the Pacific Crest Trail
#   📖 Procesando: Where'd You Go, Bernadette
#   📖 Procesando: Twilight (Twilight #1)
#   📖 Procesando: The Paris Wife
#   📖 Procesando: The Maze Runner (The Maze Runner #1)
#   📖 Procesando: The Lover's Dictionary
#   📖 Procesando: The Goldfinch
#   📖 Procesando: The Giver (The Giver Quartet #1)
#   📖 Procesando: The Girl Who Played with Fire (Millennium Trilogy #2)
#   📖 Procesando: The Demon-Haunted World: Science as a Candle in the Dark
#   📖 Procesando: The Book Thief
#   📖 Procesando: The Autobiography of Malcolm X
#   📖 Procesando: Shopaholic & Baby (Shopaholic #5)
#   📖 Procesando: Quiet: The Power of Introverts in a World That Can't Stop Talking
#   📖 Procesando: Packing for Mars: The Curious Science of Life in the Void
#   📖 Procesando: Orange Is the New Black
#   📖 Procesando: One for the Money (Stephanie Plum #1)
#   📖 Procesando: Morning Star (Red Rising #3)
#   📖 Procesando: Life After Life
#   📖 Procesando: Lean In: Women, Work, and the Will to Lead
#   📖 Procesando: Is Everyone Hanging Out Without Me? (And Other Concerns)
#   📖 Procesando: Gone Girl
#   📖 Procesando: Fellside
#   📖 Procesando: Eclipse (Twilight #3)
#   📖 Procesando: Dracula
#   📖 Procesando: Dead Wake: The Last Crossing of the Lusitania
#   📖 Procesando: David and Goliath: Underdogs, Misfits, and the Art of Battling Giants
#   📖 Procesando: Dark Places
#   📖 Procesando: Breaking Dawn (Twilight #4)
#   📖 Procesando: Beautiful Creatures (Caster Chronicles #1)
#   📖 Procesando: A Visit from the Goon Squad
#   📖 Procesando: The Zombie Room
#   📖 Procesando: The Name of the Wind (The Kingkiller Chronicle #1)
#   📖 Procesando: Taking Shots (Assassins #1)
#   📖 Procesando: Shatter Me (Shatter Me #1)
#   📖 Procesando: Paradise Lost (Paradise #1)
#   📖 Procesando: On the Road (Duluoz Legend)
#   📖 Procesando: Jane Eyre
#   📖 Procesando: Frankenstein
# ✅ Categoría Default completada
#
# 📚 Scrapeando categoría: Science Fiction
# Scrapeando https://books.toscrape.com/catalogue/category/books/science-fiction_16/index.html...
#   📖 Procesando: Mesaerion: The Best Science Fiction Stories 1800-1849
#   📖 Procesando: Join
#   📖 Procesando: William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)
#   📖 Procesando: The Project
#   📖 Procesando: Soft Apocalypse
#   📖 Procesando: Sleeping Giants (Themis Files #1)
#   📖 Procesando: Arena
#   📖 Procesando: Foundation (Foundation (Publication Order) #1)
#   📖 Procesando: The Restaurant at the End of the Universe (Hitchhiker's Guide to the Galaxy #2)
#   📖 Procesando: Ready Player One
#   📖 Procesando: Life, the Universe and Everything (Hitchhiker's Guide to the Galaxy #3)
#   📖 Procesando: Dune (Dune #1)
#   📖 Procesando: Do Androids Dream of Electric Sheep? (Blade Runner #1)
#   📖 Procesando: Three Wishes (River of Time: California #1)
#   📖 Procesando: The Last Girl (The Dominion Trilogy #1)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Having the Barbarian's Baby (Ice Planet Barbarians #7.5)
# ✅ Categoría Science Fiction completada
#
# 📚 Scrapeando categoría: Sports and Games
# Scrapeando https://books.toscrape.com/catalogue/category/books/sports-and-games_17/index.html...
#   📖 Procesando: The Book of Basketball: The NBA According to The Sports Guy
#   📖 Procesando: Friday Night Lights: A Town, a Team, and a Dream
#   📖 Procesando: Sugar Rush (Offensive Line #2)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Settling the Score (The Summer Games #1)
#   📖 Procesando: Icing (Aces Hockey #2)
# ✅ Categoría Sports and Games completada
#
# 📚 Scrapeando categoría: Add a comment
# Scrapeando https://books.toscrape.com/catalogue/category/books/add-a-comment_18/index.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/add-a-comment_18/page-2.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/add-a-comment_18/page-3.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/add-a-comment_18/page-4.html...
#   📖 Procesando: The Torch Is Passed: A Harding Family Story
#   📖 Procesando: The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy
#   📖 Procesando: The Art Forger
#   📖 Procesando: On a Midnight Clear
#   📖 Procesando: Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)
#   📖 Procesando: Shobu Samurai, Project Aryoku (#3)
#   📖 Procesando: Modern Romance
#   📖 Procesando: The White Queen (The Cousins' War #1)
#   📖 Procesando: The Song of Achilles
#   📖 Procesando: The Immortal Life of Henrietta Lacks
#   📖 Procesando: The Dovekeepers
#   📖 Procesando: More Than Music (Chasing the Dream #1)
#   📖 Procesando: Code Name Verity (Code Name Verity #1)
#   📖 Procesando: Cell
#   📖 Procesando: Angels Walking (Angels Walking #1)
#   📖 Procesando: A Series of Catastrophes and Miracles: A True Story of Love, Science, and Cancer
#   📖 Procesando: A People's History of the United States
#   📖 Procesando: A Brush of Wings (Angels Walking #3)
#   📖 Procesando: Rook
#   📖 Procesando: The Midnight Watch: A Novel of the Titanic and the Californian
#   📖 Procesando: The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore
#   📖 Procesando: The Children
#   📖 Procesando: One with You (Crossfire #5)
#   📖 Procesando: Without Shame
#   📖 Procesando: Watchmen
#   📖 Procesando: A Hero's Curse (The Unseen Chronicles #1)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: 23 Degrees South: A Tropical Tale of Changing Whether...
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: The Glass Castle
#   📖 Procesando: The Drowning Girls
#   📖 Procesando: Team of Rivals: The Political Genius of Abraham Lincoln
#   📖 Procesando: John Adams
#   📖 Procesando: Good in Bed (Cannie Shapiro #1)
#   📖 Procesando: The Joy of Cooking
#   📖 Procesando: The Golden Compass (His Dark Materials #1)
#   📖 Procesando: The God Delusion
#   📖 Procesando: Pride and Prejudice
#   📖 Procesando: Mere Christianity
#   📖 Procesando: Fun Home: A Family Tragicomic
#   📖 Procesando: The Raven King (The Raven Cycle #4)
#   📖 Procesando: Find Her (Detective D.D. Warren #8)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Evicted: Poverty and Profit in the American City
#   📖 Procesando: A Game of Thrones (A Song of Ice and Fire #1)
#   📖 Procesando: A Clash of Kings (A Song of Ice and Fire #2)
#   📖 Procesando: The Tipping Point: How Little Things Can Make a Big Difference
#   📖 Procesando: The Rest Is Noise: Listening to the Twentieth Century
#   📖 Procesando: The Purpose Driven Life: What on Earth Am I Here for?
#   📖 Procesando: The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy #1)
#   📖 Procesando: The Girl Who Kicked the Hornet's Nest (Millennium Trilogy #3)
#   📖 Procesando: The End of Faith: Religion, Terror, and the Future of Reason
#   📖 Procesando: The Complete Poems
#   📖 Procesando: The Catcher in the Rye
#   📖 Procesando: The Case for Christ (Cases for Christianity)
#   📖 Procesando: The Blind Side: Evolution of a Game
#   📖 Procesando: Seven Days in the Art World
#   📖 Procesando: Sarah's Key
#   📖 Procesando: Rogue Lawyer (Rogue Lawyer #1)
#   📖 Procesando: Manuscript Found in Accra
#   📖 Procesando: Fire Bound (Sea Haven/Sisters of the Heart #5)
#   📖 Procesando: Cosmos
#   📖 Procesando: #GIRLBOSS
#   📖 Procesando: The Sense of an Ending
#   📖 Procesando: The Republic
#   📖 Procesando: The Odyssey
#   📖 Procesando: The Light of the Fireflies
#   📖 Procesando: The Iliad
#   📖 Procesando: The Communist Manifesto
#   📖 Procesando: Lord of the Flies
# ✅ Categoría Add a comment completada
#
# 📚 Scrapeando categoría: Fantasy
# Scrapeando https://books.toscrape.com/catalogue/category/books/fantasy_19/index.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/fantasy_19/page-2.html...
# Scrapeando https://books.toscrape.com/catalogue/category/books/fantasy_19/page-3.html...
#   📖 Procesando: Unicorn Tracks
#   📖 Procesando: Saga, Volume 6 (Saga (Collected Editions) #6)
#   📖 Procesando: Princess Between Worlds (Wide-Awake Princess #5)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Masks and Shadows
#   📖 Procesando: Crown of Midnight (Throne of Glass #2)
#   📖 Procesando: Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)
#   📖 Procesando: A Court of Thorns and Roses (A Court of Thorns and Roses #1)
#   📖 Procesando: Throne of Glass (Throne of Glass #1)
#   📖 Procesando: The Glittering Court (The Glittering Court #1)
#   📖 Procesando: Hollow City (Miss Peregrineâs Peculiar Children #2)
#   📖 Procesando: The Star-Touched Queen
#   📖 Procesando: The Hidden Oracle (The Trials of Apollo #1)
#   📖 Procesando: The Bane Chronicles (The Bane Chronicles #1-11)
#   📖 Procesando: Island of Dragons (Unwanteds #7)
#   📖 Procesando: Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)
#   📖 Procesando: City of Glass (The Mortal Instruments #3)
#   📖 Procesando: Searching for Meaning in Gailana
#   📖 Procesando: The Star-Touched Queen
#   📖 Procesando: A Shard of Ice (The Black Symphony Saga #1)
#   📖 Procesando: King's Folly (The Kinsman Chronicles #1)
#   📖 Procesando: Every Heart a Doorway (Every Heart A Doorway #1)
#   📖 Procesando: A Gathering of Shadows (Shades of Magic #2)
#   📖 Procesando: The Raven Boys (The Raven Cycle #1)
#   📖 Procesando: The False Prince (The Ascendance Trilogy #1)
#   📖 Procesando: Tell the Wind and Fire
#   📖 Procesando: A Feast for Crows (A Song of Ice and Fire #4)
#   📖 Procesando: The Demonists (Demonist #1)
#   📖 Procesando: The Beast (Black Dagger Brotherhood #14)
#   📖 Procesando: Paper and Fire (The Great Library #2)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Harry Potter and the Order of the Phoenix (Harry Potter #5)
#   📖 Procesando: Harry Potter and the Half-Blood Prince (Harry Potter #6)
#   📖 Procesando: Harry Potter and the Chamber of Secrets (Harry Potter #2)
#   📖 Procesando: The Rose & the Dagger (The Wrath and the Dawn #2)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Soldier (Talon #3)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Midnight Riot (Peter Grant/ Rivers of London - books #1)
# No se encontró en Google Books, intentando en BooksToScrape...
#   📖 Procesando: Heir to the Sky
#   📖 Procesando: Eragon (The Inheritance Cycle #1)
#   📖 Procesando: Darkfever (Fever #1)
#   📖 Procesando: Ash
#   📖 Procesando: A Storm of Swords (A Song of Ice and Fire #3)
# ...
#   📖 Procesando: The Collected Poems of W.B. Yeats (The Collected Works of W.B. Yeats #1)
#   📖 Procesando: The Crossover
#   📖 Procesando: Booked
#   📖 Procesando: Twenty Love Poems and a Song of Despair
# ✅ Categoría Poetry completada
#
# 📚 Scrapeando categoría: Paranormal
# Scrapeando https://books.toscrape.com/catalogue/category/books/paranormal_24/index.html...
#   📖 Procesando: Vampire Knight, Vol. 1 (Vampire Knight #1)
# ✅ Categoría Paranormal completada
#
# 📚 Scrapeando categoría: Art
# Scrapeando https://books.toscrape.com/catalogue/category/books/art_25/index.html...
#   📖 Procesando: Wall and Piece
#   📖 Procesando: Feathers: Displays of Brilliant Plumage
#   📖 Procesando: Art and Fear: Observations on the Perils (and Rewards) of Artmaking
#   📖 Procesando: The New Drawing on the Right Side of the Brain
#   📖 Procesando: History of Beauty
#   📖 Procesando: The Story of Art
#   📖 Procesando: The Art Book
#   📖 Procesando: Ways of Seeing
# ✅ Categoría Art completada
#
# 📚 Scrapeando categoría: Psychology
# Scrapeando https://books.toscrape.com/catalogue/category/books/psychology_26/index.html...
#   📖 Procesando: The Lucifer Effect: Understanding How Good People Turn Evil
#   📖 Procesando: The Golden Condom: And Other Essays on Love Lost and Found
#   📖 Procesando: It Didn't Start with You: How Inherited Family Trauma Shapes Who We Are and How to End the Cycle
#   📖 Procesando: An Unquiet Mind: A Memoir of Moods and Madness
#   📖 Procesando: Thinking, Fast and Slow
#   📖 Procesando: Civilization and Its Discontents
#   📖 Procesando: 8 Keys to Mental Health Through Exercise
# ✅ Categoría Psychology completada
#
# 📚 Scrapeando categoría: Autobiography
# Scrapeando https://books.toscrape.com/catalogue/category/books/autobiography_27/index.html...
#   📖 Procesando: The Argonauts
#   📖 Procesando: M Train
#   📖 Procesando: Lab Girl
#   📖 Procesando: Approval Junkie: Adventures in Caring Too Much
#   📖 Procesando: Running with Scissors
#   📖 Procesando: Me Talk Pretty One Day
#   📖 Procesando: Lust & Wonder
#   📖 Procesando: Life Without a Recipe
#   📖 Procesando: A Heartbreaking Work of Staggering Genius
# ✅ Categoría Autobiography completada
#
# 📚 Scrapeando categoría: Parenting
# Scrapeando https://books.toscrape.com/catalogue/category/books/parenting_28/index.html...
#   📖 Procesando: Catastrophic Happiness: Finding Joy in Childhood's Messy Years
# ✅ Categoría Parenting completada
#
# 📚 Scrapeando categoría: Adult Fiction
# Scrapeando https://books.toscrape.com/catalogue/category/books/adult-fiction_29/index.html...
#   📖 Procesando: Fifty Shades Freed (Fifty Shades #3)
# ✅ Categoría Adult Fiction completada
#
# 📚 Scrapeando categoría: Humor
# Scrapeando https://books.toscrape.com/catalogue/category/books/humor_30/index.html...
#   📖 Procesando: The Long Haul (Diary of a Wimpy Kid #9)
#   📖 Procesando: Old School (Diary of a Wimpy Kid #10)
#   📖 Procesando: I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction
#   📖 Procesando: Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened
#   📖 Procesando: Dress Your Family in Corduroy and Denim
#   📖 Procesando: Toddlers Are A**holes: It's Not Your Fault
#   📖 Procesando: When You Are Engulfed in Flames
#   📖 Procesando: Naked
#   📖 Procesando: Lamb: The Gospel According to Biff, Christ's Childhood Pal
#   📖 Procesando: Holidays on Ice
# ✅ Categoría Humor completada
#
# 📚 Scrapeando categoría: Horror
# Scrapeando https://books.toscrape.com/catalogue/category/books/horror_31/index.html...
#   📖 Procesando: Security
#   📖 Procesando: Follow You Home
#   📖 Procesando: The Loney
#   📖 Procesando: Pet Sematary
#   📖 Procesando: Doctor Sleep (The Shining #2)
#   📖 Procesando: Psycho: Sanitarium (Psycho #1.5)
#   📖 Procesando: Can You Keep a Secret? (Fear Street Relaunch #4)
# Scrapeando https://books.toscrape.com/catalogue/category/books/historical_42/index.html...
#   📖 Procesando: All the Light We Cannot See
#   📖 Procesando: The Girl You Left Behind (The Girl You Left Behind #1)
# ✅ Categoría Historical completada
#
# 📚 Scrapeando categoría: Christian
# Scrapeando https://books.toscrape.com/catalogue/category/books/christian_43/index.html...
#   📖 Procesando: (Un)Qualified: How God Uses Broken People to Do Big Things
#   📖 Procesando: Crazy Love: Overwhelmed by a Relentless God
#   📖 Procesando: Blue Like Jazz: Nonreligious Thoughts on Christian Spirituality
# ✅ Categoría Christian completada
#
# 📚 Scrapeando categoría: Suspense
# Scrapeando https://books.toscrape.com/catalogue/category/books/suspense_44/index.html...
#   📖 Procesando: Silence in the Dark (Logan Point #4)
# ✅ Categoría Suspense completada
#
# 📚 Scrapeando categoría: Short Stories
# Scrapeando https://books.toscrape.com/catalogue/category/books/short-stories_45/index.html...
#   📖 Procesando: The Grownup
# ✅ Categoría Short Stories completada
#
# 📚 Scrapeando categoría: Novels
# Scrapeando https://books.toscrape.com/catalogue/category/books/novels_46/index.html...
#   📖 Procesando: Suzie Snowflake: One beautiful flake (a self-esteem story)
# ✅ Categoría Novels completada
#
# 📚 Scrapeando categoría: Health
# Scrapeando https://books.toscrape.com/catalogue/category/books/health_47/index.html...
#   📖 Procesando: The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life
#   📖 Procesando: Eat Fat, Get Thin
#   📖 Procesando: 10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!
#   📖 Procesando: The Art and Science of Low Carbohydrate Living
# ✅ Categoría Health completada
#
# 📚 Scrapeando categoría: Politics
# Scrapeando https://books.toscrape.com/catalogue/category/books/politics_48/index.html...
#   📖 Procesando: Libertarianism for Beginners
#   📖 Procesando: Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond
#   📖 Procesando: Equal Is Unfair: America's Misguided Fight Against Income Inequality
# ✅ Categoría Politics completada
#
# 📚 Scrapeando categoría: Cultural
# Scrapeando https://books.toscrape.com/catalogue/category/books/cultural_49/index.html...
#   📖 Procesando: Amid the Chaos
# ✅ Categoría Cultural completada
#
# 📚 Scrapeando categoría: Erotica
# Scrapeando https://books.toscrape.com/catalogue/category/books/erotica_50/index.html...
#   📖 Procesando: Dark Notes
# ✅ Categoría Erotica completada
#
# 📚 Scrapeando categoría: Crime
# Scrapeando https://books.toscrape.com/catalogue/category/books/crime_51/index.html...
#   📖 Procesando: The Long Shadow of Small Ghosts: Murder and Memory in an American City
# ✅ Categoría Crime completada
#
# 🎉 MISIÓN COMPLETADA!
# 📊 Total de libros procesados: 1000
# 🗃️ Base de datos 'libros.db' lista para la acción

# %% [markdown]
# # Las 5 consultas emocionales

# %%
def ejecutar_consultas_challenge_completo():
 
    
    conn = sqlite3.connect("libros.db")
    cursor = conn.cursor()
    
    print("🕵️ INVESTIGACIÓN: VERDADES OSCURAS DE BOOKS TO SCRAPE")
    print("=" * 60)
    
    # 1. ¿Qué autor sigue publicando catástrofes de 1 estrella?
    print("\n💀 1. AUTORES QUE DEBERÍAN DEJAR DE ESCRIBIR")
    print("Comentario: Para identificar autores con consistentemente mal rating")
    print("¿Por qué importa? Ayuda a lectores a evitar decepciones y a editores a tomar mejores decisiones")
    
    cursor.execute("""
        SELECT a.nombre, COUNT(*) as libros_horribles,
               AVG(l.precio) as precio_promedio, --calcula el promedio
               GROUP_CONCAT(l.titulo, '; ') as titulos_desastrosos
        FROM autores a
        JOIN libro_autor la ON a.id = la.autor_id
        JOIN libros l ON la.libro_id = l.id
        WHERE l.rating = 'One'
        GROUP BY a.nombre
        HAVING COUNT(*) >= 2 --se usa para condiciones sobre agregadas
        ORDER BY libros_horribles DESC
        LIMIT 5
    """)
    
    resultados = cursor.fetchall()
    if resultados:
        for autor, cantidad, precio_prom, titulos in resultados:
            print(f"   😱 {autor}: {cantidad} desastres (£{precio_prom:.2f} promedio)")
            print(f"      Títulos: {titulos[:100]}...")
    else:
        print("   🎉 ¡Sorpresa! No hay autores consistentemente malos con 2+ libros")
    
    # 2. ¿Quién es el capo de la literatura barata pero bien rankeada?
    print("\n💎 2. REYES DE LA LITERATURA BARATA PERO BUENA")
    print("Comentario: Autores que ofrecen calidad sin quebrar la billetera")
    print("¿Por qué importa? Identifica oportunidades para lectores con presupuesto limitado")
    
    cursor.execute("""
        SELECT a.nombre, 
               AVG(l.precio) as precio_promedio, 
               COUNT(*) as total_libros,
               AVG(CASE l.rating 
                   WHEN 'Five' THEN 5 WHEN 'Four' THEN 4 WHEN 'Three' THEN 3
                   WHEN 'Two' THEN 2 WHEN 'One' THEN 1 ELSE 0 END) as rating_promedio,
               MIN(l.precio) as libro_mas_barato
        FROM autores a
        JOIN libro_autor la ON a.id = la.autor_id
        JOIN libros l ON la.libro_id = l.id
        WHERE l.precio < 25
        GROUP BY a.nombre
        HAVING COUNT(*) >= 2 AND rating_promedio >= 3.5
        ORDER BY rating_promedio DESC, precio_promedio ASC
        LIMIT 10
    """)
    
    resultados = cursor.fetchall()
    for autor, precio_prom, total, rating_prom, mas_barato in resultados:
        print(f"   👑 {autor}: £{precio_prom:.2f} promedio ({total} libros)")
        print(f"      Rating: {rating_prom:.1f}⭐ | Más barato: £{mas_barato:.2f}")
    
    # 3. Análisis de precios por categoría
    print("\n💰 3. CATEGORÍAS MÁS CARAS (Dónde se va tu plata)")
    print("Comentario: Identifica géneros más costosos para planificar presupuesto")
    print("¿Por qué importa? Ayuda a lectores a entender dinámicas de precios del mercado")
    
    cursor.execute("""
        SELECT c.nombre, 
               AVG(l.precio) as precio_promedio,
               MAX(l.precio) as precio_maximo,
               MIN(l.precio) as precio_minimo,
               COUNT(*) as total_libros,
               COUNT(CASE WHEN l.rating IN ('Four', 'Five') THEN 1 END) as libros_buenos
        FROM categorias c
        JOIN libros l ON c.id = l.categoria_id
        GROUP BY c.nombre
        HAVING COUNT(*) >= 3
        ORDER BY precio_promedio DESC
        LIMIT 10
    """)
    
    resultados = cursor.fetchall()
    for categoria, precio_prom, precio_max, precio_min, total, buenos in resultados:
        porcentaje_buenos = (buenos/total)*100 if total > 0 else 0
        print(f"   💸 {categoria}: £{precio_prom:.2f} promedio")
        print(f"      Rango: £{precio_min:.2f} - £{precio_max:.2f} | {porcentaje_buenos:.0f}% con 4+ estrellas")
    
    # 4. Joyas ocultas (precio bajo, rating alto)
    print("\n💍 4. JOYAS OCULTAS (Gran calidad, precio bajo)")
    print("Comentario: Libros con excelente rating pero precio accesible")
    print("¿Por qué importa? Para cuando estás en bancarrota pero con estándares altos")
    
    cursor.execute("""
        SELECT l.titulo, 
               COALESCE(a.nombre, 'Autor desconocido') as autor, 
               l.precio, l.rating, c.nombre as categoria,
               l.descripcion
        FROM libros l
        JOIN categorias c ON l.categoria_id = c.id
        LEFT JOIN libro_autor la ON l.id = la.libro_id
        LEFT JOIN autores a ON la.autor_id = a.id
        WHERE l.rating IN ('Four', 'Five') AND l.precio < 15
        ORDER BY 
            CASE l.rating WHEN 'Five' THEN 5 ELSE 4 END DESC, 
            l.precio ASC
        LIMIT 15
    """)
    
    resultados = cursor.fetchall()
    for titulo, autor, precio, rating, categoria, descripcion in resultados:
        # Toma solo los primeros 80 caracteres de la descipcion y añade puntos suspensivos si es mas larga
        desc_corta = descripcion[:80] + "..." if len(descripcion) > 80 else descripcion
        print(f"   💎 {titulo}")
        print(f"      {autor} | £{precio:.2f} | {rating}⭐ | {categoria}")
        print(f"      {desc_corta}")
        print()
    
    # 5. BONUS: ¿Por qué hay tantos libros amarillos? (Análisis de colores en títulos)
    print("\n🟡 5. EL MISTERIO DE LOS COLORES EN LOS TÍTULOS")
    print("Comentario: Análisis de frecuencia de colores mencionados en títulos")
    print("¿Por qué importa? Para entender patrones temáticos y de marketing literario")
    
    colores = ['Yellow', 'Red', 'Blue', 'Green', 'Black', 'White', 'Orange', 'Purple', 'Pink', 'Brown']
    
    for color in colores:
        cursor.execute("""
            SELECT COUNT(*) as cantidad,
                   AVG(precio) as precio_promedio,
                   GROUP_CONCAT(titulo, '; ') as ejemplos
            FROM libros 
            WHERE UPPER(titulo) LIKE ?
        """, (f'%{color.upper()}%',))
        
        resultado = cursor.fetchone()
        cantidad, precio_prom, ejemplos = resultado
        
        if cantidad > 0:
            ejemplos_cortos = ejemplos[:100] + "..." if len(ejemplos) > 100 else ejemplos
            print(f"   🎨 {color}: {cantidad} libros (£{precio_prom:.2f} promedio)")
            print(f"      Ejemplos: {ejemplos_cortos}")
    
    conn.close()

# Ejecutar consultas completas
ejecutar_consultas_challenge_completo()
# Out:
# 🕵️ INVESTIGACIÓN: VERDADES OSCURAS DE BOOKS TO SCRAPE
# ============================================================
#
# 💀 1. AUTORES QUE DEBERÍAN DEJAR DE ESCRIBIR
# Comentario: Para identificar autores con consistentemente mal rating
# ¿Por qué importa? Ayuda a lectores a evitar decepciones y a editores a tomar mejores decisiones
#    😱 Autor por determinar: 226 desastres (£34.56 promedio)
#       Títulos: The Great Railway Bazaar; The Road to Little Dribbling: Adventures of an American in Britain (Notes ...
#    😱 Product TypeBooks: 22 desastres (£22.03 promedio)
#       Títulos: Tastes Like Fear (DI Marnie Rome #3); Her Backup Boyfriend (The Sorensen Family #1); The Purest Hook...
#    😱 Natsuki Takaya: 6 desastres (£11.97 promedio)
#       Títulos: Fruits Basket, Vol. 7 (Fruits Basket #7); Fruits Basket, Vol. 5 (Fruits Basket #5); Fruits Basket, V...
#    😱 Bill Bryson: 6 desastres (£14.43 promedio)
#       Títulos: The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2); T...
#    😱 Paul Theroux: 4 desastres (£15.27 promedio)
#       Títulos: The Great Railway Bazaar; The Great Railway Bazaar; The Great Railway Bazaar; The Great Railway Baza...
#
# 💎 2. REYES DE LA LITERATURA BARATA PERO BUENA
# Comentario: Autores que ofrecen calidad sin quebrar la billetera
# ¿Por qué importa? Identifica oportunidades para lectores con presupuesto limitado
#    👑 Gene Luen Yang: £11.89 promedio (2 libros)
#       Rating: 5.0⭐ | Más barato: £11.89
#    👑 Zane Grey: £12.29 promedio (2 libros)
#       Rating: 5.0⭐ | Más barato: £12.29
#    👑 Akiko Higashimura: £13.61 promedio (2 libros)
#       Rating: 5.0⭐ | Más barato: £13.61
#    👑 Victoria Jamieson: £14.10 promedio (2 libros)
#       Rating: 5.0⭐ | Más barato: £14.10
#    👑 Everest Media,: £14.75 promedio (2 libros)
#       Rating: 5.0⭐ | Más barato: £14.75
#    👑 Frank Miller: £15.38 promedio (2 libros)
#       Rating: 5.0⭐ | Más barato: £15.38
#    👑 Jostein Gaarder: £15.94 promedio (2 libros)
#       Rating: 5.0⭐ | Más barato: £15.94
#    👑 Melanie Dickerson: £16.97 promedio (2 libros)
#       Rating: 5.0⭐ | Más barato: £16.97
#    👑 Diana Gabaldon: £20.60 promedio (3 libros)
#       Rating: 5.0⭐ | Más barato: £19.67
#    👑 Ruta Sepetys: £20.79 promedio (2 libros)
#       Rating: 5.0⭐ | Más barato: £20.79
#
# 💰 3. CATEGORÍAS MÁS CARAS (Dónde se va tu plata)
# Comentario: Identifica géneros más costosos para planificar presupuesto
# ¿Por qué importa? Ayuda a lectores a entender dinámicas de precios del mercado
#    💸 Politics: £53.61 promedio
#       Rango: £51.33 - £56.86 | 33% con 4+ estrellas
#    💸 Health: £51.45 promedio
#       Rango: £49.05 - £54.07 | 50% con 4+ estrellas
#    💸 New Adult: £46.38 promedio
#       Rango: £36.29 - £58.35 | 33% con 4+ estrellas
#    💸 Christian: £42.50 promedio
#       Rango: £25.77 - £54.00 | 33% con 4+ estrellas
#    💸 Sports and Games: £41.17 promedio
#       Rango: £24.42 - £51.22 | 40% con 4+ estrellas
#    💸 Self Help: £40.62 promedio
#       Rango: £12.08 - £52.15 | 20% con 4+ estrellas
#    💸 Fantasy: £39.59 promedio
#       Rango: £12.16 - £58.75 | 44% con 4+ estrellas
#    💸 Art: £38.52 promedio
#       Rango: £10.29 - £49.05 | 62% con 4+ estrellas
#    💸 History: £37.29 promedio
#       Rango: £11.45 - £59.64 | 33% con 4+ estrellas
#    💸 Autobiography: £37.05 promedio
#       Rango: £10.93 - £59.04 | 44% con 4+ estrellas
#
# 💍 4. JOYAS OCULTAS (Gran calidad, precio bajo)
# Comentario: Libros con excelente rating pero precio accesible
# ¿Por qué importa? Para cuando estás en bancarrota pero con estándares altos
#    💎 An Abundance of Katherines
#       Autor desconocido | £10.00 | Five⭐ | Young Adult
#       Descripción no disponible
#
#    💎 An Abundance of Katherines
#       Autor por determinar | £10.00 | Five⭐ | Young Adult
#       Descripción no disponible
#
#    💎 An Abundance of Katherines
#       John Green | £10.00 | Five⭐ | Young Adult
#       From the #1 bestselling author of The Fault in Our Stars Michael L. Printz Honor...
#
#    💎 Greek Mythic History
#       Autor desconocido | £10.23 | Five⭐ | Default
#       Descripción no disponible
#
#    💎 Greek Mythic History
#       Autor por determinar | £10.23 | Five⭐ | Default
#       Descripción no disponible
#
#    💎 Greek Mythic History
#       History Brought Alive | £10.23 | Five⭐ | Default
#       Chaos was the origin of everything, the beginning of time. From Chaos sprang for...
#
#    💎 The Power Greens Cookbook: 140 Delicious Superfood Recipes
#       Autor por determinar | £11.05 | Five⭐ | Food and Drink
#       Descripción no disponible
#
#    💎 The Power Greens Cookbook: 140 Delicious Superfood Recipes
#       Dana Jacobi | £11.05 | Five⭐ | Food and Drink
#       140 delicious, healthy recipes for dark, leafy greens that will please your pala...
#
#    💎 Dear Mr. Knightley
#       Autor desconocido | £11.21 | Five⭐ | Fiction
#       Descripción no disponible
#
#    💎 Dear Mr. Knightley
#       Autor por determinar | £11.21 | Five⭐ | Fiction
#       Descripción no disponible
#
#    💎 Dear Mr. Knightley
#       Katherine Reay | £11.21 | Five⭐ | Fiction
#       Samantha's only friends were characters in books, but her real life takes an ext...
#
#    💎 The Darkest Corners
#       Autor desconocido | £11.33 | Five⭐ | Young Adult
#       Descripción no disponible
#
#    💎 The Darkest Corners
#       Autor por determinar | £11.33 | Five⭐ | Young Adult
#       Descripción no disponible
#
#    💎 The Darkest Corners
#       Kara Thomas | £11.33 | Five⭐ | Young Adult
#       The Darkest Corners is a psychological thriller about the lies little girls tell...
#
#    💎 Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories
#       Autor por determinar | £11.38 | Five⭐ | Food and Drink
#       Descripción no disponible
#
#
# 🟡 5. EL MISTERIO DE LOS COLORES EN LOS TÍTULOS
# Comentario: Análisis de frecuencia de colores mencionados en títulos
# ¿Por qué importa? Para entender patrones temáticos y de marketing literario
#    🎨 Yellow: 7 libros (£21.72 promedio)
#       Ejemplos: Shadow Rites (Jane Yellowrock #10); Shadow Rites (Jane Yellowrock #10); Shadow Rites (Jane Yellowroc...
#    🎨 Red: 159 libros (£27.32 promedio)
#       Ejemplos: See America: A Celebration of Our National Parks & Treasured Sites; The Red Tent; Red Hood/Arsenal, ...
#    🎨 Blue: 36 libros (£38.00 promedio)
#       Ejemplos: Girl in the Blue Coat; Something Blue (Darcy & Rachel #2); Blue Lily, Lily Blue (The Raven Cycle #3)...
#    🎨 Green: 19 libros (£20.55 promedio)
#       Ejemplos: Green Eggs and Ham (Beginner Books B-16); The Power Greens Cookbook: 140 Delicious Superfood Recipes...
#    🎨 Black: 77 libros (£35.38 promedio)
#       Ejemplos: Black Butler, Vol. 1 (Black Butler #1); Black Dust; Dark Lover (Black Dagger Brotherhood #1); Black ...
#    🎨 White: 32 libros (£38.91 promedio)
#       Ejemplos: Death Note, Vol. 5: Whiteout (Death Note #5); The White Cat and the Monk: A Retelling of the Poem â...
#    🎨 Orange: 16 libros (£34.97 promedio)
#       Ejemplos: orange: The Complete Collection 1 (orange: The Complete Collection #1); Orange Is the New Black; ora...
#    🎨 Brown: 16 libros (£30.42 promedio)
#       Ejemplos: My Mrs. Brown; Kill 'Em and Leave: Searching for James Brown and the American Soul; My Mrs. Brown; K...

# %%
import sqlite3
import time
def demostrar_indexacion():
    """
    Demostración dramática del poder de los índices
    """
    print("\n⚡ DEMOSTRACIÓN DE INDEXACIÓN: ANTES Y DESPUÉS")
    print("=" * 60)
    
    conn = sqlite3.connect("libros.db")
    cursor = conn.cursor()
    
    # Primero, ELIMINAR todos los índices para empezar limpio
    print("🧹 Limpiando índices existentes...")
    cursor.execute("DROP INDEX IF EXISTS idx_libros_precio")
    cursor.execute("DROP INDEX IF EXISTS idx_libros_rating")
    cursor.execute("DROP INDEX IF EXISTS idx_libro_autor_libro")
    cursor.execute("DROP INDEX IF EXISTS idx_libro_autor_autor")
    cursor.execute("DROP INDEX IF EXISTS idx_libros_categoria")
    
    # Consulta compleja que será lenta sin índices
    consulta_compleja = """
        SELECT l.titulo, a.nombre as autor, l.precio, l.rating, c.nombre as categoria
        FROM libros l
        JOIN libro_autor la ON l.id = la.libro_id
        JOIN autores a ON la.autor_id = a.id
        JOIN categorias c ON l.categoria_id = c.id
        WHERE l.precio > 20 AND l.rating IN ('Four', 'Five')
        ORDER BY l.precio DESC, l.titulo
        LIMIT 50
    """
    
    print("\n🐌 ANTES: Sin índices (preparate para el sufrimiento)")
    start_time = time.time()
    cursor.execute(consulta_compleja)
    resultados_sin_indice = cursor.fetchall()
    tiempo_sin_indice = time.time() - start_time
    print(f"   ⏱️  Tiempo sin índices: {tiempo_sin_indice:.4f} segundos")
    print(f"   📊 Resultados encontrados: {len(resultados_sin_indice)}")
    
    # Crear índices estratégicos
    print("\n🔧 Creando índices mágicos...")
    indices = [
        ("idx_libros_precio", "CREATE INDEX idx_libros_precio ON libros(precio)"),
        ("idx_libros_rating", "CREATE INDEX idx_libros_rating ON libros(rating)"),
        ("idx_libro_autor_libro", "CREATE INDEX idx_libro_autor_libro ON libro_autor(libro_id)"),
        ("idx_libro_autor_autor", "CREATE INDEX idx_libro_autor_autor ON libro_autor(autor_id)"),
        ("idx_libros_categoria", "CREATE INDEX idx_libros_categoria ON libros(categoria_id)")
    ]
    
    for nombre, sql in indices:
        cursor.execute(sql)
        print(f"   ✅ Creado: {nombre}")
    
    print("\n🚀 DESPUÉS: Con índices (siente el poder)")
    start_time = time.time()
    cursor.execute(consulta_compleja)
    resultados_con_indice = cursor.fetchall()
    tiempo_con_indice = time.time() - start_time
    print(f"   ⏱️  Tiempo con índices: {tiempo_con_indice:.4f} segundos")
    print(f"   📊 Resultados encontrados: {len(resultados_con_indice)}")
    
    # Calcular mejora
    if tiempo_sin_indice > 0:
        mejora_porcentaje = ((tiempo_sin_indice - tiempo_con_indice) / tiempo_sin_indice) * 100
        factor_mejora = tiempo_sin_indice / tiempo_con_indice if tiempo_con_indice > 0 else "∞"
        print(f"\n🎯 MEJORA DE RENDIMIENTO:")
        print(f"   📈 {mejora_porcentaje:.1f}% más rápido")
        if isinstance(factor_mejora, (int, float)):
            print(f"   ⚡ {factor_mejora:.2f}x más veloz")
    
    # Mostrar algunos resultados
    print("\n📋 Algunos libros caros pero buenos encontrados:")
    for i, (titulo, autor, precio, rating, categoria) in enumerate(resultados_con_indice[:8]):
        print(f"   {i+1:2d}. {titulo} - {autor}")
        precio_float = float(precio.replace("£", "").replace("Â", "").strip())
        print(f"       £{precio_float:.2f} | {rating}⭐ | {categoria}")
    conn.close()

# Ejecutar demostración de indexación
demostrar_indexacion()
# Out:
# ⚡ DEMOSTRACIÓN DE INDEXACIÓN: ANTES Y DESPUÉS
# ============================================================
# 🧹 Limpiando índices existentes...
#
# 🐌 ANTES: Sin índices (preparate para el sufrimiento)
#    ⏱️  Tiempo sin índices: 0.0161 segundos
#    📊 Resultados encontrados: 50
#
# 🔧 Creando índices mágicos...
#    ✅ Creado: idx_libros_precio
#    ✅ Creado: idx_libros_rating
#    ✅ Creado: idx_libro_autor_libro
#    ✅ Creado: idx_libro_autor_autor
#    ✅ Creado: idx_libros_categoria
#
# 🚀 DESPUÉS: Con índices (siente el poder)
#    ⏱️  Tiempo con índices: 0.0194 segundos
#    📊 Resultados encontrados: 50
#
# 🎯 MEJORA DE RENDIMIENTO:
#    📈 -20.3% más rápido
#    ⚡ 0.83x más veloz
#
# 📋 Algunos libros caros pero buenos encontrados:
#     1. The Man Who Mistook His Wife for a Hat and Other Clinical Tales - Oliver Sacks
#        £59.45 | Four⭐ | Nonfiction
#     2. The Death of Humanity: and the Case for Life - Richard Weikart
#        £58.11 | Four⭐ | Philosophy
#     3. The White Cat and the Monk: A Retelling of the Poem âPangur BÃ¡nâ - Product TypeBooks
#        £58.08 | Four⭐ | Childrens
#     4. Digital Fortress - DAN BROWN
#        £58.00 | Five⭐ | Fiction
#     5. Travels with Charley: In Search of America - John Steinbeck
#        £57.82 | Five⭐ | Nonfiction
#     6. The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1) - Alexander McCall Smith
#        £57.70 | Four⭐ | Mystery
#     7. El Deafo - Cece Bell
#        £57.62 | Five⭐ | Sequential Art
#     8. H is for Hawk - Helen Macdonald
#        £57.42 | Five⭐ | Nonfiction
